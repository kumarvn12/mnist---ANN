# %%
from __future__ import print_function

# %%
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#import MNIST data
import os
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
import tensorflow as tf
import model
import hy_param

# %%
X = model.X
Y = model.Y

# %%
checkpoint_dir = os.path.abspath(os.path.join(hy_param.checkpoint_dir, "checkpoints"))
checkpoint_prefix = os.path.join(checkpoint_dir, "model")
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
saver = tf.train.Saver(tf.global_variables(), max_to_keep=2)

# %%
init = tf.global_variables_initializer()
all_loss = []

# %%
with tf.Session() as sess:
    writer_1 = tf.summary.FileWriter("./runs/summary/", sess.graph)
    
    sum_var = tf.summary.scalar("loss", model.accuracy)
    write_op = tf.summary.merge_all()
    
    sess.run(init)
    for step in range(1, hy_param.num_steps+1) :
        batch_x, batch_y = mnist.train.next_batch(hy_param.batch_size)
        sess.run(model.train_op, feed_dict = {X: batch_x, Y:batch_y})
        if step % hy_param.display_step == 0 or step ==1:
            loss, acc , summary = sess.run([model.loss_op ,  model.accuracy, write_op], feed_dict = {X:batch_x, Y:batch_y})
            all_loss.append(loss)
            writer_1.add_summary(summary, step)
            print("Step" + str(step) + ", Minibatch Loss = " + \
                 "{:.4f}".format(loss) + ", Trianing Accuracy = " + \
                 "{:.3f}".format(acc))
        if step % hy_param.checkpoint_every == 0:
            path = saver.save(
                        sess, checkpoint_prefix, global_step=step)
        print("accuracy: ", \
        sess.run(model.accuracy, feed_dict={X: mnist.test.images,
                                       Y: mnist.test.labels}))
# Out:
# Step1, Minibatch Loss = 2745.6396, Trianing Accuracy = 0.266
# accuracy:  0.1944
# Step2, Minibatch Loss = 1977.3624, Trianing Accuracy = 0.406
# accuracy:  0.3027
# Step3, Minibatch Loss = 1593.2085, Trianing Accuracy = 0.461
# accuracy:  0.3899
# Step4, Minibatch Loss = 1082.2731, Trianing Accuracy = 0.539
# accuracy:  0.4763
# Step5, Minibatch Loss = 852.3918, Trianing Accuracy = 0.617
# accuracy:  0.5628
# Step6, Minibatch Loss = 829.0729, Trianing Accuracy = 0.594
# accuracy:  0.5653
# Step7, Minibatch Loss = 764.6910, Trianing Accuracy = 0.609
# accuracy:  0.6267
# Step8, Minibatch Loss = 862.8839, Trianing Accuracy = 0.656
# accuracy:  0.6765
# Step9, Minibatch Loss = 760.5112, Trianing Accuracy = 0.711
# accuracy:  0.6912
# Step10, Minibatch Loss = 380.2850, Trianing Accuracy = 0.789
# accuracy:  0.7034
# Step11, Minibatch Loss = 527.8245, Trianing Accuracy = 0.766
# accuracy:  0.7148
# Step12, Minibatch Loss = 729.4426, Trianing Accuracy = 0.727
# accuracy:  0.7331
# Step13, Minibatch Loss = 600.9199, Trianing Accuracy = 0.750
# accuracy:  0.7527
# Step14, Minibatch Loss = 511.0921, Trianing Accuracy = 0.789
# accuracy:  0.7726
# Step15, Minibatch Loss = 390.0597, Trianing Accuracy = 0.797
# accuracy:  0.7846
# Step16, Minibatch Loss = 396.2732, Trianing Accuracy = 0.820
# accuracy:  0.7752
# Step17, Minibatch Loss = 414.5274, Trianing Accuracy = 0.781
# accuracy:  0.7804
# Step18, Minibatch Loss = 567.1147, Trianing Accuracy = 0.828
# accuracy:  0.795
# Step19, Minibatch Loss = 462.9295, Trianing Accuracy = 0.797
# accuracy:  0.8134
# Step20, Minibatch Loss = 360.3741, Trianing Accuracy = 0.820
# accuracy:  0.8171
# Step21, Minibatch Loss = 330.7365, Trianing Accuracy = 0.820
# accuracy:  0.8174
# Step22, Minibatch Loss = 404.0730, Trianing Accuracy = 0.828
# accuracy:  0.8185
# Step23, Minibatch Loss = 589.1855, Trianing Accuracy = 0.766
# accuracy:  0.821
# Step24, Minibatch Loss = 267.2268, Trianing Accuracy = 0.836
# accuracy:  0.8252
# Step25, Minibatch Loss = 402.1127, Trianing Accuracy = 0.805
# accuracy:  0.8235
# Step26, Minibatch Loss = 199.6193, Trianing Accuracy = 0.836
# accuracy:  0.8308
# Step27, Minibatch Loss = 241.2714, Trianing Accuracy = 0.859
# accuracy:  0.8341
# Step28, Minibatch Loss = 453.8549, Trianing Accuracy = 0.805
# accuracy:  0.8335
# Step29, Minibatch Loss = 353.1041, Trianing Accuracy = 0.867
# accuracy:  0.8318
# Step30, Minibatch Loss = 511.9853, Trianing Accuracy = 0.797
# accuracy:  0.8325
# Step31, Minibatch Loss = 415.1650, Trianing Accuracy = 0.812
# accuracy:  0.8342
# Step32, Minibatch Loss = 308.1846, Trianing Accuracy = 0.789
# accuracy:  0.8373
# Step33, Minibatch Loss = 435.9285, Trianing Accuracy = 0.852
# accuracy:  0.8436
# Step34, Minibatch Loss = 178.8147, Trianing Accuracy = 0.883
# accuracy:  0.8522
# Step35, Minibatch Loss = 171.0045, Trianing Accuracy = 0.891
# accuracy:  0.8551
# Step36, Minibatch Loss = 347.6367, Trianing Accuracy = 0.836
# accuracy:  0.8521
# Step37, Minibatch Loss = 279.9496, Trianing Accuracy = 0.844
# accuracy:  0.8404
# Step38, Minibatch Loss = 480.2903, Trianing Accuracy = 0.773
# accuracy:  0.8402
# Step39, Minibatch Loss = 425.5063, Trianing Accuracy = 0.805
# accuracy:  0.8461
# Step40, Minibatch Loss = 288.4535, Trianing Accuracy = 0.859
# accuracy:  0.8546
# Step41, Minibatch Loss = 217.6045, Trianing Accuracy = 0.883
# accuracy:  0.8598
# Step42, Minibatch Loss = 304.7034, Trianing Accuracy = 0.852
# accuracy:  0.8564
# Step43, Minibatch Loss = 251.8755, Trianing Accuracy = 0.875
# accuracy:  0.8514
# Step44, Minibatch Loss = 251.1523, Trianing Accuracy = 0.844
# accuracy:  0.848
# Step45, Minibatch Loss = 355.5833, Trianing Accuracy = 0.852
# accuracy:  0.8531
# Step46, Minibatch Loss = 285.9817, Trianing Accuracy = 0.828
# accuracy:  0.8615
# Step47, Minibatch Loss = 277.9872, Trianing Accuracy = 0.836
# accuracy:  0.8611
# Step48, Minibatch Loss = 238.1150, Trianing Accuracy = 0.828
# accuracy:  0.8529
# Step49, Minibatch Loss = 397.2799, Trianing Accuracy = 0.781
# accuracy:  0.8492
# Step50, Minibatch Loss = 163.4699, Trianing Accuracy = 0.867
# accuracy:  0.8465
# Step51, Minibatch Loss = 431.6691, Trianing Accuracy = 0.828
# accuracy:  0.8607
# Step52, Minibatch Loss = 358.5726, Trianing Accuracy = 0.820
# accuracy:  0.8598
# Step53, Minibatch Loss = 209.1648, Trianing Accuracy = 0.867
# accuracy:  0.8532
# Step54, Minibatch Loss = 191.3865, Trianing Accuracy = 0.836
# accuracy:  0.8486
# Step55, Minibatch Loss = 165.8626, Trianing Accuracy = 0.898
# accuracy:  0.8572
# Step56, Minibatch Loss = 135.5221, Trianing Accuracy = 0.914
# accuracy:  0.8613
# Step57, Minibatch Loss = 67.5751, Trianing Accuracy = 0.930
# accuracy:  0.8632
# Step58, Minibatch Loss = 252.4897, Trianing Accuracy = 0.867
# accuracy:  0.8621
# Step59, Minibatch Loss = 157.6130, Trianing Accuracy = 0.906
# accuracy:  0.8547
# Step60, Minibatch Loss = 82.7426, Trianing Accuracy = 0.906
# accuracy:  0.8571
# Step61, Minibatch Loss = 271.8665, Trianing Accuracy = 0.836
# accuracy:  0.869
# Step62, Minibatch Loss = 165.1783, Trianing Accuracy = 0.875
# accuracy:  0.8722
# Step63, Minibatch Loss = 176.8035, Trianing Accuracy = 0.859
# accuracy:  0.8585
# Step64, Minibatch Loss = 293.7950, Trianing Accuracy = 0.828
# accuracy:  0.8456
# Step65, Minibatch Loss = 146.8388, Trianing Accuracy = 0.891
# accuracy:  0.8539
# Step66, Minibatch Loss = 143.3527, Trianing Accuracy = 0.852
# accuracy:  0.8681
# Step67, Minibatch Loss = 153.9698, Trianing Accuracy = 0.914
# accuracy:  0.8621
# Step68, Minibatch Loss = 161.3990, Trianing Accuracy = 0.875
# accuracy:  0.8465
# Step69, Minibatch Loss = 422.1965, Trianing Accuracy = 0.836
# accuracy:  0.8373
# Step70, Minibatch Loss = 239.5723, Trianing Accuracy = 0.836
# accuracy:  0.8418
# Step71, Minibatch Loss = 221.5591, Trianing Accuracy = 0.828
# accuracy:  0.8537
# Step72, Minibatch Loss = 288.9923, Trianing Accuracy = 0.836
# accuracy:  0.8617
# Step73, Minibatch Loss = 60.3120, Trianing Accuracy = 0.922
# accuracy:  0.8622
# Step74, Minibatch Loss = 283.5984, Trianing Accuracy = 0.844
# accuracy:  0.8546
# Step75, Minibatch Loss = 250.0315, Trianing Accuracy = 0.828
# accuracy:  0.8412
# Step76, Minibatch Loss = 167.7875, Trianing Accuracy = 0.836
# accuracy:  0.844
# Step77, Minibatch Loss = 230.2307, Trianing Accuracy = 0.852
# accuracy:  0.8573
# Step78, Minibatch Loss = 239.2899, Trianing Accuracy = 0.852
# accuracy:  0.8708
# Step79, Minibatch Loss = 324.8406, Trianing Accuracy = 0.828
# accuracy:  0.8712
# Step80, Minibatch Loss = 179.3701, Trianing Accuracy = 0.859
# accuracy:  0.8661
# Step81, Minibatch Loss = 151.3377, Trianing Accuracy = 0.914
# accuracy:  0.8646
# Step82, Minibatch Loss = 146.8713, Trianing Accuracy = 0.922
# accuracy:  0.8601
# Step83, Minibatch Loss = 290.5383, Trianing Accuracy = 0.852
# accuracy:  0.8683
# Step84, Minibatch Loss = 418.4959, Trianing Accuracy = 0.812
# accuracy:  0.8713
# Step85, Minibatch Loss = 207.5910, Trianing Accuracy = 0.867
# accuracy:  0.8686
# Step86, Minibatch Loss = 133.7237, Trianing Accuracy = 0.852
# accuracy:  0.8664
# Step87, Minibatch Loss = 147.8315, Trianing Accuracy = 0.898
# accuracy:  0.8698
# Step88, Minibatch Loss = 222.3236, Trianing Accuracy = 0.844
# accuracy:  0.8757
# Step89, Minibatch Loss = 327.4242, Trianing Accuracy = 0.812
# accuracy:  0.8814
# Step90, Minibatch Loss = 94.3349, Trianing Accuracy = 0.891
# accuracy:  0.8815
# Step91, Minibatch Loss = 148.2096, Trianing Accuracy = 0.875
# accuracy:  0.8731
# Step92, Minibatch Loss = 190.0154, Trianing Accuracy = 0.883
# accuracy:  0.8638
# Step93, Minibatch Loss = 159.2066, Trianing Accuracy = 0.898
# accuracy:  0.8587
# Step94, Minibatch Loss = 85.2355, Trianing Accuracy = 0.875
# accuracy:  0.8598
# Step95, Minibatch Loss = 240.9028, Trianing Accuracy = 0.867
# accuracy:  0.8613
# Step96, Minibatch Loss = 138.4696, Trianing Accuracy = 0.898
# accuracy:  0.8637
# Step97, Minibatch Loss = 212.4504, Trianing Accuracy = 0.867
# accuracy:  0.8644
# Step98, Minibatch Loss = 258.6605, Trianing Accuracy = 0.859
# accuracy:  0.8718
# Step99, Minibatch Loss = 315.2653, Trianing Accuracy = 0.852
# accuracy:  0.876
# Step100, Minibatch Loss = 185.9544, Trianing Accuracy = 0.914
# accuracy:  0.8715
